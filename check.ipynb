# %%
import pandas as pd

# %%
# Replace 'file_path.csv' with the actual path to your CSV file
file_path = 'data_source/customer_data_history.csv'

# Load CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)
# Display the DataFrame

# %%
df
# Out:
#        Unnamed: 0  CLIENTNUM  idstatus  Customer_Age Gender  Dependent_count  \
# 0               0  768805383         1            45      M                3
# 1               1  818770008         1            49      F                5
# 2               2  713982108         1            51      M                3
# 3               3  769911858         1            40      F                4
# 4               4  709106358         1            40      M                3
# ...           ...        ...       ...           ...    ...              ...
# 10122       10122  772366833         1            50      M                2
# 10123       10123  710638233         2            41      M                2
# 10124       10124  716506083         2            44      F                1
# 10125       10125  717406983         2            30      M                2
# 10126       10126  714337233         2            43      F                2
#
# ...

# %%
df['Income_Category'].unique()
# Out:
# array(['Rp 5.000.000 - Rp 8.000.000', '< Rp 3.000.000',
#        'Rp 8.000.000 - Rp 15.000.000', 'Rp 3.000.000 - Rp 5.000.000',
#        '> Rp 15.000.000', 'Unknown'], dtype=object)

# %%
#[Income_Category]=="< Rp 3.000.000"?"1":([Income_Category]=="Rp 3.000.000 - Rp 5.000.000"?"2":([Income_Category]=="Rp 5.000.000 - Rp 8.000.000"?"3":([Income_Category]=="Rp 8.000.000 - Rp 15.000.000"?"4":([Income_Category]=="> Rp 15.000.000"?"5":"0"))))

# %%
# Replace 'file_path.csv' with the actual path to your CSV file
file_path = 'data_destination/customer_data_history_clean.csv'

# Load CSV file into a Pandas DataFrame
df_clean = pd.read_csv(file_path)

# %%
df_clean
# Out:
#        Client_ID  Status_ID  Customer_Age Gender  Dependent_Count  \
# 0      768805383          1            45      M                3
# 1      818770008          1            49      F                5
# 2      713982108          1            51      M                3
# 3      769911858          1            40      F                4
# 4      709106358          1            40      M                3
# ...          ...        ...           ...    ...              ...
# 10122  772366833          1            50      M                2
# 10123  710638233          2            41      M                2
# 10124  716506083          2            44      F                1
# 10125  717406983          2            30      M                2
# 10126  714337233          2            43      F                2
#
#        Education_ID  Marital_ID  Income_Category_ID  Card_Category_ID  \
# 0                 1           1                   3                 1
# ...
